# %%
import IPython.display as ipd
from tqdm.auto import tqdm
from pathlib import Path
from youtube_dl import YoutubeDL
from slugify import slugify
import pandas as pd
import requests
import treelib
import json

AUDIOSET_PATH = Path("../datasets/audioset")
AUDIOSET_PATH.mkdir(exist_ok=True, parents=True)
ONTOLOGY_URL = "https://raw.githubusercontent.com/audioset/ontology/master/ontology.json"
ONTOLOGY_PATH = AUDIOSET_PATH / "ontology.json"
SEGMENTS_URL = "http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/balanced_train_segments.csv"
SEGMENTS_PATH = AUDIOSET_PATH / "segments.csv"

def download_file(url: str, path: Path):
    print(f"Downloading {path.name}...", end=" ", flush=True)
    res = requests.get(url, allow_redirects=True)
    with open(path, "wb") as file:
        file.write(res.content)
    print("OK")
    
download_file(ONTOLOGY_URL, ONTOLOGY_PATH)
download_file(SEGMENTS_URL, SEGMENTS_PATH)
# Out:
# Downloading ontology.json... OK
# Downloading segments.csv... OK

# %%
ontology_df = pd.read_json(str(ONTOLOGY_PATH))
good_columns = ["id", "name", "description", "child_ids"]
ontology_df.drop(ontology_df.columns.difference(good_columns), 1, inplace=True)
ontology_df.style.set_properties(subset=["description"], **{"width": "600px"})
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
ipd.display(ontology_df)
pd.set_option("display.max_rows", 50)
# Out:
#                 id                                      name  \
# 0        /m/0dgw9r                              Human sounds
# 1         /m/09l8g                               Human voice
# 2         /m/09x0r                                    Speech
# 3        /m/05zppz                 Male speech, man speaking
# 4         /m/02zsn             Female speech, woman speaking
# 5         /m/0ytgt                Child speech, kid speaking
# 6        /m/01h8n0                              Conversation
# 7        /m/02qldy                      Narration, monologue
# 8        /m/0261r1                                  Babbling
# 9         /m/0brhx                        Speech synthesizer
# 10      /m/07p6fty                                     Shout
# 11      /m/07q4ntr                                    Bellow
# 12      /m/07rwj3x                                     Whoop
# 13      /m/07sr1lc                                      Yell
# 14       /m/04gy_2                                Battle cry
# 15      /t/dd00135                         Children shouting
# 16      /m/03qc9zr                                 Screaming
# 17      /m/02rtxlg                                Whispering
# 18       /m/01j3sz                                  Laughter
# 19      /t/dd00001                             Baby laughter
# 20      /m/07r660_                                    Giggle
# 21      /m/07s04w4                                   Snicker
# 22      /m/07sq110                               Belly laugh
# 23      /m/07rgt08                          Chuckle, chortle
# 24      /m/0463cq4                           Crying, sobbing
# 25      /t/dd00002                      Baby cry, infant cry
# 26      /m/07qz6j3                                   Whimper
# 27      /m/07qw_06                                Wail, moan
# 28      /m/07plz5l                                      Sigh
# 29       /m/015lz1                                   Singing
# 30       /m/0l14jd                                     Choir
# 31       /m/01swy6                                  Yodeling
# 32       /m/02bk07                                     Chant
# 33       /m/01c194                                    Mantra
# 34      /t/dd00003                              Male singing
# 35      /t/dd00004                            Female singing
# 36      /t/dd00005                             Child singing
# 37      /t/dd00006                         Synthetic singing
# 38        /m/06bxc                                   Rapping
# 39       /m/02fxyj                                   Humming
# 40      /m/07s2xch                                     Groan
# 41      /m/07r4k75                                     Grunt
# 42       /m/01j423                                      Yawn
# 43       /m/01w250                                 Whistling
# 44       /m/079vc8                            Wolf-whistling
# 45       /m/09hlz4                        Respiratory sounds
# 46        /m/0lyf6                                 Breathing
# 47       /m/07mzm6                                    Wheeze
# 48       /m/01d3sd                                   Snoring
# 49      /m/07s0dtb                                      Gasp
# 50      /m/07pyy8b                                      Pant
# 51      /m/07q0yl5                                     Snort
# 52       /m/01b_21                                     Cough
# 53      /m/0dl9sf8                           Throat clearing
# 54       /m/01hsr_                                    Sneeze
# 55      /m/07ppn3j                                     Sniff
# 56      /m/0bpl036                          Human locomotion
# 57        /m/06h7j                                       Run
# 58      /m/07qv_x_                                   Shuffle
# 59      /m/07pbtc8                           Walk, footsteps
# 60       /m/0160x5                                 Digestive
# 61       /m/03cczk                      Chewing, mastication
# 62      /m/07pdhp0                                    Biting
# 63       /m/0939n_                                  Gargling
# 64       /m/01g90h                            Stomach rumble
# 65       /m/03q5_w                       Burping, eructation
# 66       /m/02p3nc                                    Hiccup
# 67        /m/02_nn                                      Fart
# 68        /m/0k65p                                     Hands
# 69      /m/025_jnm                           Finger snapping
# 70       /m/0l15bq                                  Clapping
# 71       /m/01jg02                   Heart sounds, heartbeat
# 72       /m/01jg1z                              Heart murmur
# 73       /m/04xp5v                      Otoacoustic emission
# 74        /m/0pv6y             Tinnitus, ringing in the ears
# 75      /t/dd00012                       Human group actions
# 76       /m/053hz1                                  Cheering
# 77       /m/028ght                                  Applause
# 78      /m/07rkbfh                                   Chatter
# 79       /m/03qtwd                                     Crowd
# 80      /m/07qfr4h       Hubbub, speech noise, speech babble
# 81       /m/04v5dt                                    Booing
# 82      /t/dd00013                          Children playing
# 83         /m/0jbk                                    Animal
# 84        /m/068hy                    Domestic animals, pets
# 85       /m/0bt9lr                                       Dog
# 86       /m/05tny_                                      Bark
# 87      /m/07r_k2n                                       Yip
# 88      /m/07qf0zm                                      Howl
# 89      /m/07rc7d9                                   Bow-wow
# 90       /m/0ghcn6                                  Growling
# 91      /t/dd00136                             Whimper (dog)
# 92      /m/07srf8z                                       Bay
# 93        /m/01yrx                                       Cat
# 94       /m/02yds9                                      Purr
# 95      /m/07qrkrw                                      Meow
# 96      /m/07rjwbb                                      Hiss
# 97       /m/0f25s6                         Cat communication
# 98      /m/07r81j2                                 Caterwaul
# 99        /m/0ch8v  Livestock, farm animals, working animals
# 100       /m/03k3r                                     Horse
# 101     /m/07rv9rh                                 Clip-clop
# 102     /m/07q5rw0                             Neigh, whinny
# 103     /t/dd00139                             Snort (horse)
# 104     /t/dd00140                                    Nicker
# 105       /m/0ffhf                               Donkey, ass
# 106     /m/01xq0k1                           Cattle, bovinae
# 107     /m/07rpkh9                                       Moo
# 108      /m/0239kh                                   Cowbell
# 109      /m/01hhp3                                       Yak
# 110       /m/068zj                                       Pig
# 111     /t/dd00018                                      Oink
# 112       /m/03fwl                                      Goat
# 113     /m/07q0h5t                                     Bleat
# 114       /m/07bgp                                     Sheep
# 115     /m/025rv6n                                      Fowl
# 116       /m/09b5t                          Chicken, rooster
# 117     /m/07st89h                                     Cluck
# 118     /m/07qn5dc                Crowing, cock-a-doodle-doo
# 119      /m/01rd7k                                    Turkey
# 120     /m/07svc2k                                    Gobble
# 121       /m/09ddx                                      Duck
# 122     /m/07qdb04                                     Quack
# 123       /m/0dbvp                                     Goose
# 124     /m/07qwf61                                      Honk
# 125      /m/01280g                              Wild animals
# 126       /m/0cdnk              Roaring cats (lions, tigers)
# 127     /m/04cvmfc                                      Roar
# 128       /m/015p6                                      Bird
# 129      /m/020bb7   Bird vocalization, bird call, bird song
# 130     /m/07pggtn                              Chirp, tweet
# 131     /m/07sx8x_                                    Squawk
# 132       /m/0h0rv                              Pigeon, dove
# 133     /m/07r_25d                                       Coo
# 134      /m/04s8yn                                      Crow
# 135     /m/07r5c2p                                       Caw
# 136       /m/09d5_                                       Owl
# 137     /m/07r_80w                                      Hoot
# 138      /m/01dwxx                             Gull, seagull
# 139      /m/05_wcq               Bird flight, flapping wings
# 140       /m/01z5f                     Canidae, dogs, wolves
# 141       /m/06hps                       Rodents, rats, mice
# 142       /m/04rmv                                     Mouse
# 143       /m/02021                                  Chipmunk
# 144     /m/07r4gkf                                    Patter
# 145       /m/03vt0                                    Insect
# 146       /m/09xqv                                   Cricket
# 147       /m/09f96                                  Mosquito
# 148       /m/0h2mp                             Fly, housefly
# 149     /m/07pjwq1                                      Buzz
# 150       /m/01h3n                           Bee, wasp, etc.
# 151       /m/09ld4                                      Frog
# 152     /m/07st88b                                     Croak
# 153       /m/078jl                                     Snake
# 154     /m/07qn4z3                                    Rattle
# 155      /m/032n05                        Whale vocalization
# 156       /m/04rlf                                     Music
# 157       /m/04szw                        Musical instrument
# 158      /m/0fx80y                 Plucked string instrument
# 159       /m/0342h                                    Guitar
# 160       /m/02sgy                           Electric guitar
# 161       /m/018vs                               Bass guitar
# 162     /m/042v_gx                           Acoustic guitar
# 163       /m/06w87                Steel guitar, slide guitar
# 164      /m/01glhc                Tapping (guitar technique)
# 165     /m/07s0s5r                                     Strum
# 166       /m/018j2                                     Banjo
# 167       /m/0jtg0                                     Sitar
# 168       /m/04rzd                                  Mandolin
# 169      /m/01bns_                                    Zither
# 170       /m/07xzm                                   Ukulele
# 171     /m/05148p4                        Keyboard (musical)
# 172       /m/05r5c                                     Piano
# 173      /m/01s0ps                            Electric piano
# 174      /m/025cbm                                  Clavinet
# 175       /m/0bxl5                              Rhodes piano
# 176      /m/013y1f                                     Organ
# 177      /m/03xq_f                          Electronic organ
# 178       /m/03gvt                             Hammond organ
# 179      /m/0l14qv                               Synthesizer
# 180      /m/01v1d8                                   Sampler
# 181       /m/0gkd1                                 Mellotron
# 182       /m/03q5t                               Harpsichord
# 183      /m/0l14md                                Percussion
# 184       /m/02hnl                                  Drum kit
# 185       /m/0cfdd                              Drum machine
# 186       /m/026t6                                      Drum
# 187       /m/06rvn                                Snare drum
# 188      /m/03t3fj                                   Rimshot
# 189      /m/02k_mr                                 Drum roll
# 190       /m/0bm02                                 Bass drum
# 191      /m/011k_j                                   Timpani
# 192      /m/01p970                                     Tabla
# 193       /m/01qbl                                    Cymbal
# 194       /m/03qtq                                    Hi-hat
# 195       /m/0bm0k                              Crash cymbal
# 196      /m/01sm1g                                Wood block
# 197       /m/07brj                                Tambourine
# 198      /m/05r5wn                       Rattle (instrument)
# 199       /m/0xzly                                    Maraca
# 200       /m/0mbct                                      Gong
# 201      /m/016622                             Tubular bells
# 202     /m/0j45pbj                         Mallet percussion
# 203       /m/0dwsp                        Marimba, xylophone
# 204       /m/0dwtp                              Glockenspiel
# 205       /m/0dwt5                                Vibraphone
# 206      /m/0l156b                                  Steelpan
# 207       /m/05pd6                                 Orchestra
# 208       /m/01kcd                          Brass instrument
# 209       /m/0319l                               French horn
# 210       /m/07gql                                   Trumpet
# 211       /m/07c6l                                  Trombone
# 212       /m/020w2                                    Cornet
# 213       /m/0y64j                                     Bugle
# 214      /m/0l14_3                   Bowed string instrument
# 215     /m/02qmj0d                            String section
# 216       /m/07y_7                            Violin, fiddle
# 217       /m/0d8_n                                 Pizzicato
# 218       /m/01xqw                                     Cello
# 219       /m/02fsn                               Double bass
# 220       /m/085jw      Wind instrument, woodwind instrument
# 221      /m/0l14j_                                     Flute
# 222       /m/06ncr                                 Saxophone
# 223      /m/02pprs                            Alto saxophone
# 224      /m/03t22m                         Soprano saxophone
# 225       /m/01wy6                                  Clarinet
# 226       /m/05kms                                      Oboe
# 227       /m/01c3q                                   Bassoon
# 228       /m/03m5k                                      Harp
# 229      /m/0395lw                                      Bell
# 230      /m/03w41f                               Church bell
# 231     /m/027m70_                               Jingle bell
# 232     /m/0gy1t2s                              Bicycle bell
# 233       /m/07n_g                               Tuning fork
# 234      /m/0f8s22                                     Chime
# 235      /m/026fgl                                Wind chime
# 236      /m/0150b9              Change ringing (campanology)
# 237       /m/03qjg                                 Harmonica
# 238        /m/0mkg                                 Accordion
# 239       /m/0192l                                  Bagpipes
# 240       /m/02bxd                                Didgeridoo
# 241      /m/0l14l2                                    Shofar
# 242       /m/07kc_                                  Theremin
# 243      /m/0l14t7                              Singing bowl
# 244       /m/05229                          Musical ensemble
# 245      /m/01vj9c                    Bass (instrument role)
# 246      /m/01hgjl        Scratching (performance technique)
# 247      /m/0kpv1t                               Music genre
# 248       /m/064t9                                 Pop music
# 249     /m/0glt670                             Hip hop music
# 250      /m/04j_h4                               Grime music
# 251     /m/0n8zsc8                                Trap music
# 252      /m/02cz_7                                Beatboxing
# 253       /m/06by7                                Rock music
# 254       /m/03lty                               Heavy metal
# 255       /m/05r6t                                 Punk rock
# 256       /m/0dls3                                    Grunge
# 257       /m/0dl5d                          Progressive rock
# 258     /m/07sbbz2                             Rock and roll
# 259       /m/05w3f                          Psychedelic rock
# 260       /m/06j6l                          Rhythm and blues
# 261       /m/0gywn                                Soul music
# 262       /m/06cqb                                    Reggae
# 263      /m/0190y4                                       Dub
# 264       /m/01lyv                                   Country
# 265      /m/015y_n                               Swing music
# 266       /m/0gg8l                                 Bluegrass
# 267       /m/02x8m                                      Funk
# 268       /m/02w4v                                Folk music
# 269      /m/06j64v                      Middle Eastern music
# 270       /m/03_d0                                      Jazz
# 271       /m/026z9                                     Disco
# 272      /m/0ggq0m                           Classical music
# 273       /m/05lls                                     Opera
# 274       /m/02lkt                          Electronic music
# 275       /m/03mb9                               House music
# 276       /m/07gxw                                    Techno
# 277      /m/07s72n                                   Dubstep
# 278      /m/029h7y                                   Electro
# 279       /m/0283d                             Drum and bass
# 280      /m/01f9gb                          Oldschool jungle
# 281       /m/0m0jc                               Electronica
# 282      /m/08cyft                    Electronic dance music
# 283       /m/0fd3y                             Ambient music
# 284      /m/052smk                               Drone music
# 285       /m/07lnk                              Trance music
# 286       /m/0m0fw                               Noise music
# 287      /m/0bmfpc                                 UK garage
# 288       /m/0g293                    Music of Latin America
# 289      /m/02ccj9                                    Cumbia
# 290       /m/0ln16                               Salsa music
# 291       /m/0kpck                                Soca music
# 292      /m/080nby                                    Kuduro
# 293      /m/05q7ms                              Funk carioca
# 294       /m/0326g                                  Flamenco
# 295       /m/0155w                                     Blues
# 296      /m/05fw6t                        Music for children
# 297      /m/02v2lh                             New-age music
# 298       /m/0y4f8                               Vocal music
# 299        /m/0z9c                                 A capella
# 300      /m/0164x2                           Music of Africa
# 301       /m/0145m                                  Afrobeat
# 302      /m/022dgg                                    Kwaito
# 303      /m/02mscn                           Christian music
# 304      /m/016cjb                              Gospel music
# 305      /m/028sqc                             Music of Asia
# 306      /m/015vgc                            Carnatic music
# 307      /m/0dq0md                        Music of Bollywood
# 308       /m/06rqw                                       Ska
# 309     /m/02p0sh1                         Traditional music
# 310      /m/05rwpb                         Independent music
# 311     /t/dd00027                          Musical concepts
# 312       /m/074ft                                      Song
# 313       /m/09dsr                                    Melody
# 314       /m/05jcn                              Musical note
# 315      /m/022c7z                                      Beat
# 316      /m/05xp3j                                 Drum beat
# 317      /m/01gp74                                     Chord
# 318       /m/0b128                                   Harmony
# 319      /m/021wwz                                  Bassline
# 320       /m/0kc2j                                      Loop
# 321      /m/03w6d1                                     Drone
# 322     /t/dd00028                                Music role
# 323     /m/025td0t                          Background music
# 324      /m/02cjck                               Theme music
# 325      /m/03r5q_                            Jingle (music)
# 326      /m/0l14gg                          Soundtrack music
# 327     /m/07pkxdp                                   Lullaby
# 328      /m/01z7dr                          Video game music
# 329      /m/0140xf                           Christmas music
# 330      /m/0ggx5q                               Dance music
# 331      /m/04wptg                             Wedding music
# 332     /t/dd00029                            Birthday music
# 333     /t/dd00030                                Music mood
# 334     /t/dd00031                               Happy music
# 335     /t/dd00032                               Funny music
# 336     /t/dd00033                                 Sad music
# 337     /t/dd00034                              Tender music
# 338     /t/dd00035                            Exciting music
# 339     /t/dd00036                               Angry music
# 340     /t/dd00037                               Scary music
# 341      /m/059j3w                            Natural sounds
# 342     /m/03m9d0z                                      Wind
# 343     /m/07q8f3b                               Howl (wind)
# 344       /m/09t49                           Rustling leaves
# 345     /t/dd00092                   Wind noise (microphone)
# 346       /m/0jb2l                              Thunderstorm
# 347       /m/0ngt1                                   Thunder
# 348       /m/0838f                                     Water
# 349       /m/06mb1                                      Rain
# 350     /m/07r10fb                                  Raindrop
# 351     /t/dd00038                           Rain on surface
# 352       /m/0j6m2                                    Stream
# 353       /m/0j2kx                                 Waterfall
# 354       /m/05kq4                                     Ocean
# 355      /m/034srq                               Waves, surf
# 356       /m/06wzb                                     Steam
# 357     /m/07swgks                                  Gurgling
# 358       /m/02_41                                      Fire
# 359     /m/07pzfmf                                   Crackle
# 360       /m/0fjy1                                  Wildfire
# 361     /t/dd00041                          Sounds of things
# 362       /m/07yv9                                   Vehicle
# 363       /m/019jd                       Boat, Water vehicle
# 364       /m/0hsrw                    Sailboat, sailing ship
# 365      /m/056ks2                     Rowboat, canoe, kayak
# 366      /m/02rlv9                      Motorboat, speedboat
# 367       /m/06q74                                      Ship
# 368      /m/012f08                      Motor vehicle (road)
# 369        /m/0k4j                                       Car
# 370      /m/0912c9           Vehicle horn, car horn, honking
# 371     /m/07qv_d5                                      Toot
# 372      /m/02mfyn                                 Car alarm
# 373      /m/04gxbd           Power windows, electric windows
# 374     /m/07rknqz                                  Skidding
# 375       /m/0h9mv                               Tire squeal
# 376     /t/dd00134                            Car passing by
# 377        /m/0ltv                     Race car, auto racing
# 378       /m/07r04                                     Truck
# 379      /m/0gvgw0                                 Air brake
# 380      /m/05x_td                      Air horn, truck horn
# 381     /m/02rhddq                           Reversing beeps
# 382      /m/03cl9h            Ice cream truck, ice cream van
# 383       /m/01bjv                                       Bus
# 384      /m/03j1ly                         Emergency vehicle
# 385      /m/04qvtq                        Police car (siren)
# 386      /m/012n7d                         Ambulance (siren)
# 387      /m/012ndj           Fire engine, fire truck (siren)
# 388       /m/04_sv                                Motorcycle
# 389       /m/0btp2              Traffic noise, roadway noise
# 390       /m/06d_3                            Rail transport
# 391       /m/07jdr                                     Train
# 392      /m/04zmvq                             Train whistle
# 393     /m/0284vy3                                Train horn
# 394      /m/01g50p                 Railroad car, train wagon
# 395     /t/dd00048                    Train wheels squealing
# 396      /m/0195fx                Subway, metro, underground
# 397        /m/0k5j                                  Aircraft
# 398      /m/014yck                           Aircraft engine
# 399       /m/04229                                Jet engine
# 400      /m/02l6bg                       Propeller, airscrew
# 401       /m/09ct_                                Helicopter
# 402       /m/0cmf2             Fixed-wing aircraft, airplane
# 403     /t/dd00061                Non-motorized land vehicle
# 404       /m/0199g                                   Bicycle
# 405       /m/06_fw                                Skateboard
# 406       /m/02mk9                                    Engine
# 407     /t/dd00065             Light engine (high frequency)
# 408      /m/08j51y             Dental drill, dentist's drill
# 409      /m/01yg9g                                Lawn mower
# 410      /m/01j4z9                                  Chainsaw
# 411     /t/dd00066             Medium engine (mid frequency)
# 412     /t/dd00067              Heavy engine (low frequency)
# 413      /m/01h82_                           Engine knocking
# 414     /t/dd00130                           Engine starting
# 415     /m/07pb8fc                                    Idling
# 416     /m/07q2z82              Accelerating, revving, vroom
# 417     /t/dd00071              Domestic sounds, home sounds
# 418       /m/02dgv                                      Door
# 419      /m/03wwcy                                  Doorbell
# 420     /m/07r67yg                                 Ding-dong
# 421     /m/02y_763                              Sliding door
# 422     /m/07rjzl8                                      Slam
# 423     /m/07r4wb8                                     Knock
# 424     /m/07qcpgn                                       Tap
# 425     /m/07q6cd_                                    Squeak
# 426      /m/0642b4                    Cupboard open or close
# 427      /m/0fqfqc                      Drawer open or close
# 428      /m/04brg2                    Dishes, pots, and pans
# 429      /m/023pjk                       Cutlery, silverware
# 430     /m/07pn_8q                           Chopping (food)
# 431       /m/0dxrf                             Frying (food)
# 432       /m/0fx9l                            Microwave oven
# 433      /m/02pjr4                                   Blender
# 434  /g/11b630rrvh                            Kettle whistle
# 435      /m/02jz0l                         Water tap, faucet
# 436      /m/0130jx                 Sink (filling or washing)
# 437      /m/03dnzn              Bathtub (filling or washing)
# 438      /m/03wvsk                                Hair dryer
# 439      /m/01jt3m                              Toilet flush
# 440      /m/012xff                                Toothbrush
# 441      /m/04fgwm                       Electric toothbrush
# 442       /m/0d31p                            Vacuum cleaner
# 443      /m/01s0vc                         Zipper (clothing)
# 444     /m/0zmy2j9            Velcro, hook and loop fastener
# 445      /m/03v3yw                             Keys jangling
# 446       /m/0242l                           Coin (dropping)
# 447     /m/05mxj0q                   Packing tape, duct tape
# 448      /m/01lsmm                                  Scissors
# 449      /m/02g901           Electric shaver, electric razor
# 450       /m/05rj2                           Shuffling cards
# 451      /m/0316dw                                    Typing
# 452       /m/0c2wf                                Typewriter
# 453       /m/01m2v                         Computer keyboard
# 454       /m/081rb                                   Writing
# 455     /m/07pp_mv                                     Alarm
# 456       /m/07cx4                                 Telephone
# 457     /m/07pp8cl                    Telephone bell ringing
# 458      /m/01hnzm                                  Ringtone
# 459      /m/01sb50           Cellphone buzz, vibrating alert
# 460       /m/02c8p                   Telephone dialing, DTMF
# 461      /m/015jpf                                 Dial tone
# 462      /m/01z47d                               Busy signal
# 463      /m/046dlr                               Alarm clock
# 464      /m/03kmc9                                     Siren
# 465       /m/0dgbq                       Civil defense siren
# 466      /m/030rvx                                    Buzzer
# 467      /m/01y3hg               Smoke detector, smoke alarm
# 468      /m/0c3f7m                                Fire alarm
# 469      /m/04fq5q                                   Foghorn
# 470      /m/0l156k                                   Whistle
# 471      /m/06hck5                             Steam whistle
# 472     /t/dd00077                                Mechanisms
# 473      /m/02bm9n                             Ratchet, pawl
# 474       /m/01x3z                                     Clock
# 475     /m/07qjznt                                      Tick
# 476     /m/07qjznl                                 Tick-tock
# 477       /m/0l7xg                                     Gears
# 478       /m/05zc1                                   Pulleys
# 479       /m/0llzx                            Sewing machine
# 480     /m/02x984l                            Mechanical fan
# 481     /m/025wky1                          Air conditioning
# 482       /m/024dl                             Cash register
# 483       /m/01m4t                                   Printer
# 484       /m/0dv5r                                    Camera
# 485       /m/07bjf                 Single-lens reflex camera
# 486       /m/07k1x                                     Tools
# 487       /m/03l9g                                    Hammer
# 488      /m/03p19w                                Jackhammer
# 489      /m/01b82r                                    Sawing
# 490      /m/02p01q                             Filing (rasp)
# 491      /m/023vsd                                   Sanding
# 492       /m/0_ksk                                Power tool
# 493      /m/01d380                                     Drill
# 494      /m/014zdl                                 Explosion
# 495      /m/032s66                          Gunshot, gunfire
# 496       /m/04zjc                               Machine gun
# 497     /m/02z32qm                                 Fusillade
# 498        /m/0_1c                            Artillery fire
# 499      /m/073cg4                                   Cap gun
# 500       /m/0g6b5                                 Fireworks
# 501    /g/122z_qxw                               Firecracker
# 502     /m/07qsvvw                                Burst, pop
# 503     /m/07pxg6y                                  Eruption
# 504     /m/07qqyl4                                      Boom
# 505      /m/0193bn                                Sonic boom
# 506       /m/083vt                                      Wood
# 507     /m/07pczhz                                      Chop
# 508     /m/07pl1bw                                  Splinter
# 509     /m/07qs1cx                                     Crack
# 510     /m/07pc8l3                                      Snap
# 511       /m/039jq                                     Glass
# 512     /m/07q7njn                              Chink, clink
# 513     /m/07rn7sz                                   Shatter
# 514       /m/04k94                                    Liquid
# 515     /m/07rrlb6                          Splash, splatter
# 516     /m/07p6mqd                                     Slosh
# 517     /m/07qlwh6                                    Squish
# 518     /m/07r5v4s                                      Drip
# 519     /m/07prgkl                                      Pour
# 520     /m/07pqc89                          Trickle, dribble
# 521     /t/dd00088                                      Gush
# 522     /m/07p7b8y                        Fill (with liquid)
# 523     /m/07qlf79                                     Spray
# 524     /m/07ptzwd                             Pump (liquid)
# 525     /m/07ptfmf                                      Stir
# 526       /m/0dv3j                                   Boiling
# 527     /t/dd00089                     Miscellaneous sources
# 528       /m/0790c                                     Sonar
# 529     /m/04179zz                  Duck call (hunting tool)
# 530       /m/0dl83                                     Arrow
# 531     /m/07rqsjt                     Whoosh, swoosh, swish
# 532     /m/07qnq_y                               Thump, thud
# 533     /m/07rrh0c                                     Thunk
# 534     /t/dd00108                                     Clunk
# 535     /m/07pk7mg                                    Wobble
# 536     /t/dd00091                           Sound equipment
# 537       /m/0hg7b                                Microphone
# 538      /m/0b_fwt                          Electronic tuner
# 539      /m/01vfsf                          Guitar amplifier
# 540       /m/02rr_                              Effects unit
# 541      /m/07m2kt                             Chorus effect
# 542     /t/dd00133                    Specific impact sounds
# 543       /m/018w8                         Basketball bounce
# 544     /t/dd00098                   Source-ambiguous sounds
# 545     /t/dd00099                     Generic impact sounds
# 546     /m/07pws3f                                      Bang
# 547     /m/07ryjzk                               Slap, smack
# 548     /m/07rdhzs                             Whack, thwack
# 549     /m/07pjjrj                              Smash, crash
# 550     /m/07pc8lb                                  Breaking
# 551     /m/07pqn27                                  Bouncing
# 552     /m/07rbp7_                                      Whip
# 553     /m/07pyf11                                      Flap
# 554     /t/dd00109                           Surface contact
# 555     /m/07qb_dv                                   Scratch
# 556     /m/07qv4k0                                    Scrape
# 557     /m/07pdjhy                                       Rub
# 558     /m/07s8j8t                                      Roll
# 559     /m/07pt6mm                                     Grind
# 560     /t/dd00110                          Deformable shell
# 561     /m/07plct2                                  Crushing
# 562     /t/dd00112                      Crumpling, crinkling
# 563     /m/07qcx4z                                   Tearing
# 564       /m/05n1m                              Onomatopoeia
# 565    /t/dd000138                                Brief tone
# 566      /m/02fs_r                               Beep, bleep
# 567     /m/07qwdck                                      Ping
# 568     /m/07phxs1                                      Ding
# 569     /m/07rv4dm                                     Clang
# 570     /m/07rpk1c                                     Twang
# 571     /m/07s02z0                                    Squeal
# 572     /m/07q8k13                                   Screech
# 573     /m/07qh7jl                                     Creak
# 574     /m/07qwyj0                                    Rustle
# 575     /m/07s34ls                                      Whir
# 576     /m/07qmpdm                                   Clatter
# 577     /m/07p9k1k                                    Sizzle
# 578     /m/07qc9xj                                  Clicking
# 579     /m/07rwm0c                            Clickety-clack
# 580     /m/07phhsh                                    Rumble
# 581     /m/07r_r9m                                     Blare
# 582     /m/07qyrcz                                      Plop
# 583     /m/07qfgpx                            Jingle, tinkle
# 584     /t/dd00118                                      Fizz
# 585     /m/07q34h3                                      Puff
# 586     /m/07rcgpl                                       Hum
# 587     /m/07p78v5                                      Zing
# 588     /t/dd00121                                     Boing
# 589     /m/07s12q4                                    Crunch
# 590      /m/028v0c                                   Silence
# 591     /t/dd00122                          Other sourceless
# 592      /m/01v_m0                                 Sine wave
# 593       /m/0b9m1                                  Harmonic
# 594       /m/0hdsk                                Chirp tone
# 595       /m/0c1dj                              Sound effect
# 596     /m/07pt_g0                                     Pulse
# 597      /m/01fhw5                                Infrasound
# 598       /m/017gp                    Bass (frequency range)
# 599     /m/05szwhw                    Ringing (of resonator)
# 600     /t/dd00123       Channel, environment and background
# 601     /t/dd00093                      Acoustic environment
# 602     /t/dd00125                        Inside, small room
# 603     /t/dd00126                Inside, large room or hall
# 604     /t/dd00127                      Inside, public space
# 605     /t/dd00128                 Outside, urban or manmade
# 606     /t/dd00129                 Outside, rural or natural
# 607      /m/01b9nn                             Reverberation
# 608      /m/01jnbd                                      Echo
# 609      /m/096m7z                                     Noise
# 610      /m/093_4n                          Background noise
# 611     /m/06_y0by                       Environmental noise
# 612      /m/09d1b1                                 Tape hiss
# 613     /m/07rgkc5                                    Static
# 614      /m/06xkwv                                 Mains hum
# 615      /m/0g12c5                                Distortion
# 616      /m/08p9q4                                  Sidetone
# 617     /m/07szfh9                                 Cacophony
# 618       /m/0chx_                               White noise
# 619       /m/0cj0r                                Pink noise
# 620     /m/07p_0gm                                 Throbbing
# 621      /m/01jwx6                                 Vibration
# 622      /m/07bm98                        Sound reproduction
# 623       /m/07c52                                Television
# 624       /m/06bz3                                     Radio
# 625       /m/0cfpc                               Loudspeaker
# 626      /m/01b7fy                                Headphones
# 627      /m/025l19                                 Recording
# 628      /m/07hvw1                           Field recording
# 629      /m/0174nj                         Gramophone record
# 630       /m/01www                              Compact disc
# 631       /m/04zc0                                       MP3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                               Sounds produced by the human body through the actions of the individual.
# 1                                                                                                                                                                                                                                          The human voice consists of sound made by a human being using the vocal folds for talking, singing, laughing, crying, screaming, etc. The human voice is specifically a part of human sound production in which the vocal folds are the primary sound source.
# 2                                                                                                                                                                                                                                                                                                                                               Speech is the vocalized form of human communication, created out of the phonetic combination of a limited set of vowel and consonant speech sound units.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Speech uttered by an adult male human.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                               Speech uttered by an adult female human.
# 5                                                                                                                                                                                                                                                                                                                                                                                                      Speech uttered by a human child, i.e. a human whose voice does not yet resemble that of an adult.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                              Interactive, spontaneous spoken communication between two or more people.
# 7                                                                                                                                                                                                                                                                                                                                                                                                         Speech by a single human aimed at an audience (either present or assumed, as in a video blog).
# 8                                                                                                                                                                                                                                                                                                                                     Speech-like sounds uttered by a human that lack the deeper structure and meaning of conventional speech. Babbling is a stage in a child's development of language.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Artificially-produced human speech.
# 10                                                                                                                                                                                                                                                                                                                                           Talk in a loud voice to deliberately command attention or overcome interfering sounds. Does not have the stronger emotional connotations of Yell or Scream.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                  A very loud utterance by a person that seems more animal than human.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                       A loud hooting cry of exultation or excitement.
# 13                                                                                                                                                                                                                                                                                                 Utter or declare in a very loud voice that seems excessive or involuntary, or that is deliberately startling in order to command attention, as distinct from the pragmatically raised voice of Shout.
# ...
# 580                                                                                                                                                                                                                                                                                                         []
# 581                                                                                                                                                                                                                                                                                                         []
# 582                                                                                                                                                                                                                                                                                                         []
# 583                                                                                                                                                                                                                                                                                                         []
# 584                                                                                                                                                                                                                                                                                                         []
# 585                                                                                                                                                                                                                                                                                                         []
# 586                                                                                                                                                                                                                                                                                                         []
# 587                                                                                                                                                                                                                                                                                                         []
# 588                                                                                                                                                                                                                                                                                                         []
# 589                                                                                                                                                                                                                                                                                                         []
# 590                                                                                                                                                                                                                                                                                                         []
# 591                                                                                                                                                                                                                                         [/m/01v_m0, /m/0c1dj, /m/07pt_g0, /m/01fhw5, /m/017gp, /m/05szwhw]
# 592                                                                                                                                                                                                                                                                                       [/m/0b9m1, /m/0hdsk]
# 593                                                                                                                                                                                                                                                                                                         []
# 594                                                                                                                                                                                                                                                                                                         []
# 595                                                                                                                                                                                                                                                                                                         []
# 596                                                                                                                                                                                                                                                                                                         []
# 597                                                                                                                                                                                                                                                                                                         []
# 598                                                                                                                                                                                                                                                                                                         []
# 599                                                                                                                                                                                                                                                                                                         []
# 600                                                                                                                                                                                                                                                                         [/t/dd00093, /m/096m7z, /m/07bm98]
# 601                                                                                                                                                                                                                         [/t/dd00125, /t/dd00126, /t/dd00127, /t/dd00128, /t/dd00129, /m/01b9nn, /m/01jnbd]
# 602                                                                                                                                                                                                                                                                                                         []
# 603                                                                                                                                                                                                                                                                                                         []
# 604                                                                                                                                                                                                                                                                                                         []
# 605                                                                                                                                                                                                                                                                                                         []
# 606                                                                                                                                                                                                                                                                                                         []
# 607                                                                                                                                                                                                                                                                                                         []
# 608                                                                                                                                                                                                                                                                                                         []
# 609                                                                                                                                                                                                                             [/m/093_4n, /m/07qfr4h, /m/07szfh9, /m/0chx_, /m/0cj0r, /m/07p_0gm, /m/01jwx6]
# 610                                                                                                                                                                                                                                       [/m/06_y0by, /m/09d1b1, /m/07rgkc5, /m/06xkwv, /m/0g12c5, /m/08p9q4]
# 611                                                                                                                                                                                                                                                                                                         []
# 612                                                                                                                                                                                                                                                                                                         []
# 613                                                                                                                                                                                                                                                                                                         []
# 614                                                                                                                                                                                                                                                                                                         []
# 615                                                                                                                                                                                                                                                                                                         []
# 616                                                                                                                                                                                                                                                                                                         []
# 617                                                                                                                                                                                                                                                                                                         []
# 618                                                                                                                                                                                                                                                                                                         []
# 619                                                                                                                                                                                                                                                                                                         []
# 620                                                                                                                                                                                                                                                                                                         []
# 621                                                                                                                                                                                                                                                                                                         []
# 622                                                                                                                                                                                                                        [/m/07c52, /m/06bz3, /m/0cfpc, /m/01b7fy, /m/025l19, /m/0174nj, /m/01www, /m/04zc0]
# 623                                                                                                                                                                                                                                                                                                         []
# 624                                                                                                                                                                                                                                                                                                         []
# 625                                                                                                                                                                                                                                                                                                         []
# 626                                                                                                                                                                                                                                                                                                         []
# 627                                                                                                                                                                                                                                                                                                [/m/07hvw1]
# 628                                                                                                                                                                                                                                                                                                         []
# 629                                                                                                                                                                                                                                                                                                         []
# 630                                                                                                                                                                                                                                                                                                         []
# 631                                                                                                                                                                                                                                                                                                         []

# %%
id_to_slug = {}
clean_classes = {}
for _, x in ontology_df.iterrows():
    slug = slugify(x["name"])
    assert slug not in clean_classes
    id_to_slug[x["id"]] = slug
    clean_classes[slug] = {
        "id": x["id"],
        "description": x["description"],
        "children": x["child_ids"],
    }

for i, (k, x) in enumerate(clean_classes.items()):
    x["children"] = [id_to_slug[c] for c in x["children"]]
    for child in x["children"]:
        clean_classes[child]["parent"] = k

tree = treelib.Tree()
tree_nodes = {"root": tree.create_node("*")}
failing = True
while failing:
    failing = False
    for k, v in clean_classes.items():
        if k in tree_nodes:
            continue
        parent = v.get("parent", "root")
        if parent not in tree_nodes:
            failing = True
            continue
        node = tree.create_node(k, parent=tree_nodes[parent])
        tree_nodes[k] = node

print("AUDIOSET CLASS HIERARCHY:")
tree.show()
# Out:
# AUDIOSET CLASS HIERARCHY:
# *
# ├── animal
# │   ├── domestic-animals-pets
# │   │   ├── cat
# │   │   │   ├── cat-communication
# │   │   │   ├── caterwaul
# │   │   │   ├── meow
# │   │   │   └── purr
# │   │   └── dog
# │   │       ├── bark
# │   │       ├── bay
# │   │       ├── bow-wow
# │   │       ├── whimper-dog
# │   │       └── yip
# │   ├── livestock-farm-animals-working-animals
# │   │   ├── cattle-bovinae
# │   │   │   ├── moo
# │   │   │   └── yak
# │   │   ├── donkey-ass
# │   │   ├── fowl
# │   │   │   ├── chicken-rooster
# │   │   │   │   ├── cluck
# │   │   │   │   └── crowing-cock-a-doodle-doo
# │   │   │   ├── duck
# │   │   │   │   └── quack
# │   │   │   ├── goose
# │   │   │   │   └── honk
# │   │   │   └── turkey
# │   │   │       └── gobble
# │   │   ├── goat
# │   │   ├── horse
# │   │   │   ├── neigh-whinny
# │   │   │   ├── nicker
# │   │   │   └── snort-horse
# │   │   ├── pig
# │   │   │   └── oink
# │   │   └── sheep
# │   │       └── bleat
# │   └── wild-animals
# │       ├── bird
# │       │   ├── bird-flight-flapping-wings
# │       │   ├── bird-vocalization-bird-call-bird-song
# │       │   │   └── squawk
# │       │   ├── crow
# │       │   │   └── caw
# │       │   ├── gull-seagull
# │       │   ├── owl
# │       │   │   └── hoot
# │       │   └── pigeon-dove
# │       │       └── coo
# │       ├── canidae-dogs-wolves
# │       │   ├── growling
# │       │   └── howl
# │       ├── frog
# │       │   └── croak
# │       ├── insect
# │       │   ├── bee-wasp-etc
# │       │   ├── cricket
# │       │   ├── fly-housefly
# │       │   └── mosquito
# │       ├── roaring-cats-lions-tigers
# │       │   └── roar
# │       ├── rodents-rats-mice
# │       │   ├── chipmunk
# │       │   ├── mouse
# │       │   └── patter
# │       ├── snake
# │       └── whale-vocalization
# ├── channel-environment-and-background
# │   ├── acoustic-environment
# │   │   ├── echo
# │   │   ├── inside-large-room-or-hall
# │   │   ├── inside-public-space
# │   │   ├── inside-small-room
# │   │   ├── outside-rural-or-natural
# │   │   ├── outside-urban-or-manmade
# │   │   └── reverberation
# │   ├── noise
# │   │   ├── background-noise
# │   │   │   ├── distortion
# │   │   │   ├── environmental-noise
# │   │   │   ├── mains-hum
# │   │   │   ├── sidetone
# │   │   │   ├── static
# │   │   │   └── tape-hiss
# │   │   ├── cacophony
# │   │   ├── hubbub-speech-noise-speech-babble
# │   │   ├── pink-noise
# │   │   ├── throbbing
# │   │   ├── vibration
# │   │   └── white-noise
# │   └── sound-reproduction
# │       ├── compact-disc
# │       ├── gramophone-record
# │       ├── headphones
# │       ├── loudspeaker
# │       ├── mp3
# │       ├── radio
# │       ├── recording
# │       │   └── field-recording
# │       └── television
# ├── human-sounds
# │   ├── digestive
# │   │   ├── biting
# │   │   ├── burping-eructation
# │   │   ├── chewing-mastication
# │   │   ├── fart
# │   │   ├── gargling
# │   │   ├── hiccup
# │   │   └── stomach-rumble
# │   ├── hands
# │   │   └── finger-snapping
# │   ├── heart-sounds-heartbeat
# │   │   └── heart-murmur
# │   ├── human-group-actions
# │   │   ├── applause
# │   │   ├── booing
# │   │   ├── chatter
# │   │   ├── cheering
# │   │   ├── children-playing
# │   │   ├── children-shouting
# │   │   ├── clapping
# │   │   └── crowd
# │   ├── human-locomotion
# │   │   ├── run
# │   │   ├── shuffle
# │   │   └── walk-footsteps
# │   ├── human-voice
# │   │   ├── crying-sobbing
# │   │   │   ├── baby-cry-infant-cry
# │   │   │   └── whimper
# │   │   ├── groan
# │   │   ├── grunt
# │   │   ├── humming
# │   │   ├── laughter
# │   │   │   ├── baby-laughter
# │   │   │   ├── belly-laugh
# │   │   │   ├── chuckle-chortle
# │   │   │   ├── giggle
# │   │   │   └── snicker
# │   │   ├── screaming
# │   │   ├── shout
# │   │   │   ├── battle-cry
# │   │   │   ├── bellow
# │   │   │   ├── whoop
# │   │   │   └── yell
# │   │   ├── sigh
# │   │   ├── singing
# │   │   │   ├── child-singing
# │   │   │   ├── female-singing
# │   │   │   ├── male-singing
# │   │   │   ├── rapping
# │   │   │   ├── synthetic-singing
# │   │   │   └── yodeling
# │   │   ├── speech
# │   │   │   ├── babbling
# │   │   │   ├── child-speech-kid-speaking
# │   │   │   ├── conversation
# │   │   │   ├── female-speech-woman-speaking
# │   │   │   ├── male-speech-man-speaking
# │   │   │   ├── narration-monologue
# │   │   │   └── speech-synthesizer
# │   │   ├── wail-moan
# │   │   ├── whispering
# │   │   └── yawn
# │   ├── otoacoustic-emission
# │   │   └── tinnitus-ringing-in-the-ears
# │   ├── respiratory-sounds
# │   │   ├── breathing
# │   │   │   ├── gasp
# │   │   │   ├── pant
# │   │   │   ├── snoring
# │   │   │   ├── snort
# │   │   │   └── wheeze
# │   │   ├── cough
# │   │   │   └── throat-clearing
# │   │   ├── sneeze
# │   │   └── sniff
# │   └── whistling
# │       └── wolf-whistling
# ├── music
# │   ├── music-genre
# │   │   ├── blues
# │   │   ├── christian-music
# │   │   │   └── gospel-music
# │   │   ├── classical-music
# │   │   │   └── opera
# │   │   ├── country
# │   │   │   ├── bluegrass
# │   │   │   └── swing-music
# │   │   ├── disco
# │   │   ├── electronic-music
# │   │   │   ├── ambient-music
# │   │   │   │   └── drone-music
# │   │   │   ├── drum-and-bass
# │   │   │   │   └── oldschool-jungle
# │   │   │   ├── dubstep
# │   │   │   ├── electro
# │   │   │   ├── electronic-dance-music
# │   │   │   ├── electronica
# │   │   │   ├── house-music
# │   │   │   ├── noise-music
# │   │   │   ├── techno
# │   │   │   ├── trance-music
# │   │   │   └── uk-garage
# │   │   ├── folk-music
# │   │   ├── funk
# │   │   ├── hip-hop-music
# │   │   │   ├── grime-music
# │   │   │   └── trap-music
# │   │   ├── independent-music
# │   │   ├── jazz
# │   │   ├── middle-eastern-music
# │   │   ├── music-for-children
# │   │   ├── music-of-africa
# │   │   │   ├── afrobeat
# │   │   │   └── kwaito
# │   │   ├── music-of-asia
# │   │   │   ├── carnatic-music
# │   │   │   └── music-of-bollywood
# │   │   ├── music-of-latin-america
# │   │   │   ├── cumbia
# │   │   │   ├── flamenco
# │   │   │   ├── funk-carioca
# │   │   │   ├── kuduro
# │   │   │   ├── salsa-music
# │   │   │   └── soca-music
# │   │   ├── new-age-music
# │   │   ├── pop-music
# │   │   ├── reggae
# │   │   │   └── dub
# │   │   ├── rhythm-and-blues
# │   │   ├── rock-music
# │   │   │   ├── grunge
# │   │   │   ├── heavy-metal
# │   │   │   ├── progressive-rock
# │   │   │   ├── psychedelic-rock
# │   │   │   ├── punk-rock
# │   │   │   └── rock-and-roll
# │   │   ├── ska
# │   │   ├── soul-music
# │   │   ├── traditional-music
# │   │   └── vocal-music
# │   │       ├── a-capella
# │   │       ├── beatboxing
# │   │       └── chant
# │   │           └── mantra
# │   ├── music-mood
# │   │   ├── angry-music
# │   │   ├── exciting-music
# │   │   ├── funny-music
# │   │   ├── happy-music
# │   │   ├── sad-music
# │   │   ├── scary-music
# │   │   └── tender-music
# │   ├── music-role
# │   │   ├── background-music
# │   │   ├── birthday-music
# │   │   ├── christmas-music
# │   │   ├── dance-music
# │   │   ├── jingle-music
# │   │   ├── lullaby
# │   │   ├── soundtrack-music
# │   │   ├── theme-music
# │   │   ├── video-game-music
# │   │   └── wedding-music
# │   ├── musical-concepts
# │   │   ├── bassline
# │   │   ├── beat
# │   │   │   └── drum-beat
# │   │   ├── chord
# │   │   ├── drone
# │   │   ├── harmony
# │   │   ├── loop
# │   │   ├── melody
# │   │   ├── musical-note
# │   │   └── song
# │   └── musical-instrument
# │       ├── accordion
# │       ├── bagpipes
# │       ├── bass-instrument-role
# │       ├── bowed-string-instrument
# │       │   ├── cello
# │       │   ├── double-bass
# │       │   ├── string-section
# │       │   └── violin-fiddle
# │       │       └── pizzicato
# │       ├── brass-instrument
# │       │   ├── bugle
# │       │   ├── cornet
# │       │   ├── french-horn
# │       │   ├── trombone
# │       │   └── trumpet
# │       ├── choir
# │       ├── didgeridoo
# │       ├── harmonica
# │       ├── harp
# │       ├── keyboard-musical
# │       │   ├── harpsichord
# │       │   ├── organ
# │       │   │   ├── electronic-organ
# │       │   │   └── hammond-organ
# │       │   ├── piano
# │       │   │   └── electric-piano
# │       │   │       ├── clavinet
# │       │   │       └── rhodes-piano
# │       │   └── synthesizer
# │       │       ├── mellotron
# │       │       └── sampler
# │       ├── musical-ensemble
# │       ├── orchestra
# │       ├── percussion
# │       │   ├── cymbal
# │       │   │   ├── crash-cymbal
# │       │   │   └── hi-hat
# │       │   ├── drum
# │       │   │   ├── bass-drum
# │       │   │   ├── snare-drum
# │       │   │   │   ├── drum-roll
# │       │   │   │   └── rimshot
# │       │   │   ├── tabla
# │       │   │   └── timpani
# │       │   ├── drum-kit
# │       │   │   └── drum-machine
# │       │   ├── gong
# │       │   ├── mallet-percussion
# │       │   │   ├── glockenspiel
# │       │   │   ├── marimba-xylophone
# │       │   │   ├── steelpan
# │       │   │   └── vibraphone
# │       │   ├── rattle-instrument
# │       │   │   └── maraca
# │       │   ├── tambourine
# │       │   ├── tubular-bells
# │       │   └── wood-block
# │       ├── plucked-string-instrument
# │       │   ├── banjo
# │       │   ├── guitar
# │       │   │   ├── acoustic-guitar
# │       │   │   ├── bass-guitar
# │       │   │   ├── electric-guitar
# │       │   │   ├── steel-guitar-slide-guitar
# │       │   │   ├── strum
# │       │   │   └── tapping-guitar-technique
# │       │   ├── mandolin
# │       │   ├── sitar
# │       │   ├── ukulele
# │       │   └── zither
# │       ├── scratching-performance-technique
# │       ├── shofar
# │       ├── singing-bowl
# │       ├── theremin
# │       └── wind-instrument-woodwind-instrument
# │           ├── bassoon
# │           ├── clarinet
# │           ├── flute
# │           ├── oboe
# │           └── saxophone
# │               ├── alto-saxophone
# │               └── soprano-saxophone
# ├── natural-sounds
# │   ├── fire
# │   │   └── wildfire
# │   ├── thunderstorm
# │   │   └── thunder
# │   ├── water
# │   │   ├── gurgling
# │   │   ├── ocean
# │   │   │   └── waves-surf
# │   │   ├── rain
# │   │   │   ├── rain-on-surface
# │   │   │   └── raindrop
# │   │   ├── steam
# │   │   ├── stream
# │   │   └── waterfall
# │   └── wind
# │       ├── howl-wind
# │       └── rustling-leaves
# ├── sounds-of-things
# │   ├── alarm
# │   │   ├── air-horn-truck-horn
# │   │   ├── alarm-clock
# │   │   ├── bicycle-bell
# │   │   ├── buzzer
# │   │   ├── car-alarm
# │   │   ├── doorbell
# │   │   │   └── ding-dong
# │   │   ├── fire-alarm
# │   │   ├── foghorn
# │   │   ├── siren
# │   │   │   ├── ambulance-siren
# │   │   │   ├── civil-defense-siren
# │   │   │   ├── fire-engine-fire-truck-siren
# │   │   │   └── police-car-siren
# │   │   ├── smoke-detector-smoke-alarm
# │   │   ├── telephone
# │   │   │   ├── busy-signal
# │   │   │   ├── cellphone-buzz-vibrating-alert
# │   │   │   ├── dial-tone
# │   │   │   ├── ringtone
# │   │   │   ├── telephone-bell-ringing
# │   │   │   └── telephone-dialing-dtmf
# │   │   ├── vehicle-horn-car-horn-honking
# │   │   │   └── toot
# │   │   └── whistle
# │   │       ├── kettle-whistle
# │   │       └── steam-whistle
# │   ├── bell
# │   │   ├── change-ringing-campanology
# │   │   ├── chime
# │   │   │   └── wind-chime
# │   │   ├── church-bell
# │   │   ├── cowbell
# │   │   ├── jingle-bell
# │   │   └── tuning-fork
# │   ├── domestic-sounds-home-sounds
# │   │   ├── bathtub-filling-or-washing
# │   │   ├── blender
# │   │   ├── chopping-food
# │   │   ├── coin-dropping
# │   │   ├── cupboard-open-or-close
# │   │   ├── cutlery-silverware
# │   │   ├── dishes-pots-and-pans
# │   │   ├── door
# │   │   │   ├── slam
# │   │   │   └── sliding-door
# │   │   ├── drawer-open-or-close
# │   │   ├── electric-shaver-electric-razor
# │   │   ├── frying-food
# │   │   ├── hair-dryer
# │   │   ├── keys-jangling
# │   │   ├── microwave-oven
# │   │   ├── packing-tape-duct-tape
# │   │   ├── scissors
# │   │   ├── shuffling-cards
# │   │   ├── sink-filling-or-washing
# │   │   ├── toilet-flush
# │   │   ├── toothbrush
# │   │   │   └── electric-toothbrush
# │   │   ├── typing
# │   │   │   ├── computer-keyboard
# │   │   │   └── typewriter
# │   │   ├── vacuum-cleaner
# │   │   ├── velcro-hook-and-loop-fastener
# │   │   ├── water-tap-faucet
# │   │   ├── writing
# │   │   └── zipper-clothing
# │   ├── engine
# │   │   ├── accelerating-revving-vroom
# │   │   ├── engine-knocking
# │   │   ├── engine-starting
# │   │   ├── heavy-engine-low-frequency
# │   │   ├── idling
# │   │   ├── jet-engine
# │   │   ├── light-engine-high-frequency
# │   │   │   ├── chainsaw
# │   │   │   └── lawn-mower
# │   │   └── medium-engine-mid-frequency
# │   ├── explosion
# │   │   ├── boom
# │   │   │   └── sonic-boom
# │   │   ├── burst-pop
# │   │   ├── eruption
# │   │   ├── fireworks
# │   │   │   └── firecracker
# │   │   └── gunshot-gunfire
# │   │       ├── artillery-fire
# │   │       ├── cap-gun
# │   │       ├── fusillade
# │   │       └── machine-gun
# │   ├── glass
# │   │   ├── chink-clink
# │   │   └── shatter
# │   ├── liquid
# │   │   ├── boiling
# │   │   ├── drip
# │   │   ├── fill-with-liquid
# │   │   ├── pour
# │   │   │   ├── gush
# │   │   │   └── trickle-dribble
# │   │   ├── pump-liquid
# │   │   ├── splash-splatter
# │   │   │   └── slosh
# │   │   ├── spray
# │   │   └── stir
# │   ├── mechanisms
# │   │   ├── air-conditioning
# │   │   ├── camera
# │   │   │   └── single-lens-reflex-camera
# │   │   ├── cash-register
# │   │   ├── clock
# │   │   │   └── tick-tock
# │   │   ├── gears
# │   │   ├── mechanical-fan
# │   │   ├── printer
# │   │   ├── pulleys
# │   │   ├── ratchet-pawl
# │   │   └── sewing-machine
# │   ├── miscellaneous-sources
# │   │   ├── arrow
# │   │   │   └── wobble
# │   │   ├── duck-call-hunting-tool
# │   │   ├── sonar
# │   │   └── sound-equipment
# │   │       ├── effects-unit
# │   │       │   └── chorus-effect
# │   │       ├── electronic-tuner
# │   │       ├── guitar-amplifier
# │   │       └── microphone
# │   │           └── wind-noise-microphone
# │   ├── specific-impact-sounds
# │   │   └── basketball-bounce
# │   ├── tools
# │   │   ├── filing-rasp
# │   │   ├── hammer
# │   │   ├── jackhammer
# │   │   ├── power-tool
# │   │   │   └── drill
# │   │   │       └── dental-drill-dentist-s-drill
# │   │   ├── sanding
# │   │   └── sawing
# │   ├── vehicle
# │   │   ├── aircraft
# │   │   │   ├── aircraft-engine
# │   │   │   │   └── propeller-airscrew
# │   │   │   ├── fixed-wing-aircraft-airplane
# │   │   │   └── helicopter
# │   │   ├── boat-water-vehicle
# │   │   │   ├── motorboat-speedboat
# │   │   │   ├── rowboat-canoe-kayak
# │   │   │   ├── sailboat-sailing-ship
# │   │   │   └── ship
# │   │   ├── motor-vehicle-road
# │   │   │   ├── bus
# │   │   │   ├── car
# │   │   │   │   ├── car-passing-by
# │   │   │   │   ├── power-windows-electric-windows
# │   │   │   │   ├── race-car-auto-racing
# │   │   │   │   ├── skidding
# │   │   │   │   └── tire-squeal
# │   │   │   ├── emergency-vehicle
# │   │   │   ├── motorcycle
# │   │   │   ├── traffic-noise-roadway-noise
# │   │   │   └── truck
# │   │   │       ├── air-brake
# │   │   │       ├── ice-cream-truck-ice-cream-van
# │   │   │       └── reversing-beeps
# │   │   ├── non-motorized-land-vehicle
# │   │   │   ├── bicycle
# │   │   │   └── skateboard
# │   │   └── rail-transport
# │   │       ├── railroad-car-train-wagon
# │   │       ├── subway-metro-underground
# │   │       ├── train
# │   │       │   ├── train-horn
# │   │       │   └── train-whistle
# │   │       └── train-wheels-squealing
# │   └── wood
# │       ├── chop
# │       └── splinter
# └── source-ambiguous-sounds
#     ├── deformable-shell
#     │   ├── crumpling-crinkling
#     │   ├── crushing
#     │   └── tearing
#     ├── generic-impact-sounds
#     │   ├── bang
#     │   ├── bouncing
#     │   ├── breaking
#     │   ├── flap
#     │   ├── knock
#     │   ├── slap-smack
#     │   ├── smash-crash
#     │   ├── tap
#     │   ├── thump-thud
#     │   │   ├── clunk
#     │   │   └── thunk
#     │   ├── whack-thwack
#     │   └── whip
#     ├── onomatopoeia
#     │   ├── blare
#     │   ├── boing
#     │   ├── brief-tone
#     │   │   ├── beep-bleep
#     │   │   ├── buzz
#     │   │   ├── chirp-tweet
#     │   │   ├── clang
#     │   │   ├── ding
#     │   │   ├── ping
#     │   │   ├── screech
#     │   │   ├── squeak
#     │   │   ├── squeal
#     │   │   └── twang
#     │   ├── clatter
#     │   ├── clicking
#     │   │   ├── clickety-clack
#     │   │   ├── clip-clop
#     │   │   └── tick
#     │   ├── crack
#     │   ├── crackle
#     │   ├── creak
#     │   ├── crunch
#     │   ├── fizz
#     │   ├── hiss
#     │   ├── hum
#     │   ├── jingle-tinkle
#     │   ├── plop
#     │   ├── puff
#     │   ├── rattle
#     │   ├── rumble
#     │   ├── rustle
#     │   ├── sizzle
#     │   ├── snap
#     │   ├── squish
#     │   ├── whir
#     │   ├── whoosh-swoosh-swish
#     │   └── zing
#     ├── other-sourceless
#     │   ├── bass-frequency-range
#     │   ├── infrasound
#     │   ├── pulse
#     │   ├── ringing-of-resonator
#     │   ├── sine-wave
#     │   │   ├── chirp-tone
#     │   │   └── harmonic
#     │   └── sound-effect
#     ├── silence
#     └── surface-contact
#         ├── grind
#         ├── roll
#         ├── rub
#         ├── scrape
#         └── scratch

# %%
segments_df = pd.read_csv(
    SEGMENTS_PATH,
    sep=", ",
    comment="#",
    engine="python",
    names=["id", "start", "end", "classes"],
)

slug_classes = []
for index, row in tqdm(segments_df.iterrows(), total=len(segments_df)):
    classes = row["classes"].strip('"').split(",")
    classes = set(id_to_slug[x] for x in classes)
    old_classes = None
    while classes != old_classes:
        old_classes = classes.copy()
        for x in old_classes:
            parent = clean_classes[x].get("parent")
            if parent:
                classes.add(parent)
    slug_classes.append(classes)

segments_df["classes"] = pd.Series(slug_classes, dtype='O')
segments_df
# Out:
#   0%|          | 0/22160 [00:00<?, ?it/s]
#                 id  start    end  \
# 0      --PJHxphWEs   30.0   40.0
# 1      --ZhevVpy1s   50.0   60.0
# 2      --aE2O5G5WE    0.0   10.0
# 3      --aO5cdqSAg   30.0   40.0
# 4      --aaILOrkII  200.0  210.0
# ...            ...    ...    ...
# 22155  zyqg4pYEioQ   20.0   30.0
# 22156  zz0ddNfz0h0   30.0   40.0
# 22157  zz8TGV83nkE   80.0   90.0
# 22158  zzlK8KDqlr0  370.0  380.0
# 22159  zzya4dDVRLk   30.0   40.0
#
#                                                                                                                                                                                                                                            classes
# 0                                                                                                                                                                        {human-sounds, sounds-of-things, human-voice, speech, liquid, pour, gush}
# 1                                                                                                                                                                                      {toothbrush, sounds-of-things, domestic-sounds-home-sounds}
# 2                                                                                                                                                 {human-sounds, animal, goat, speech, music, livestock-farm-animals-working-animals, human-voice}
# 3                                                                                                                                                                                {human-sounds, child-singing, male-singing, singing, human-voice}
# 4                                                                                                                                                                                          {sounds-of-things, cap-gun, explosion, gunshot-gunfire}
# ...                                                                                                                                                                                                                                            ...
# 22155                                                                                                                                                            {human-sounds, sewing-machine, sounds-of-things, mechanisms, speech, human-voice}
# 22156                                                                                                                                                   {sounds-of-things, motor-vehicle-road, ice-cream-truck-ice-cream-van, truck, vehicle, car}
# 22157                                                                                                                                                                          {sounds-of-things, motor-vehicle-road, engine, motorcycle, vehicle}
# 22158  {acoustic-environment, domestic-sounds-home-sounds, human-sounds, inside-small-room, computer-keyboard, channel-environment-and-background, sounds-of-things, clicking, source-ambiguous-sounds, speech, typing, onomatopoeia, human-voice}
# 22159                                                                                                                                                                           {chirp-tone, source-ambiguous-sounds, other-sourceless, sine-wave}
#
# [22160 rows x 4 columns]

# %%
# How many samples to download (per class)
NUM = 2000

# Target audio sample rate
SAMPLE_RATE = 16000

# AUDIO CLASSES FILTER
# include = download if ANY tag matches
# exclude = DO NOT download if ANY tag mathes
GROUPS = {
    "noise": {
        "include": [
            "channel-environment-and-background",
            "natural-sounds",
            "sounds-of-things",
        ],
        "exclude": [
            "music",
            "hubbub-speech-noise-speech-babble",
            "radio",
            "television",
            "human-voice",
        ],
    },
    "music": {
        "include": ["music"],
        "exclude": [
            "hubbub-speech-noise-speech-babble",
            "radio",
            "television",
            "human-voice",
        ],
    },
}

# %%
YDL_OPTIONS = {
    "format": "bestaudio/best",
    "postprocessors": [{"key": "FFmpegExtractAudio", "preferredcodec": "wav"}],
    "postprocessor_args": "-ss {start} -to {end} -ar {sample_rate} -ac 1",
    "prefer_ffmpeg": True,
    "keepvideo": False,
    "quiet": True,
    "no_warnings": True,
}


def filter_segments(include, exclude):
    include, exclude = set(include), set(exclude)
    func = lambda x: bool(x["classes"] & include) and not bool(x["classes"] & exclude)
    return segments_df[segments_df.apply(func, axis=1)]


def seconds_to_ffmpeg_format(sec):
    sec = float(sec)
    return f"{sec // 3600:.0f}:{(sec % 3600) // 60:.0f}:{sec % 60:.0f}"


def download_segment(video_id, start, end, path):
    options = YDL_OPTIONS.copy()
    options["outtmpl"] = str(path.parent / "%(id)s.%(ext)s")
    start = seconds_to_ffmpeg_format(start)
    end = seconds_to_ffmpeg_format(end)
    args = options["postprocessor_args"]
    args = args.format(start=start, end=end, sample_rate=SAMPLE_RATE)
    options["postprocessor_args"] = args.split()
    try:
        with YoutubeDL(options) as ydl:
            ydl.download([video_id])
            return True
    except:
        path.unlink(missing_ok=True)
        return False

# %%
print("Please check following parameters are correct:")
print("Group names to download:", list(GROUPS))
print("Number of files to download (per group):", NUM)
print("Output audio sample rate:", SAMPLE_RATE)
if input("Continue? (y/n): ").strip().lower() != "y":
    print("Aborting...")
    assert False


for name, filters in GROUPS.items():
    path = AUDIOSET_PATH / name
    path.mkdir(parents=True, exist_ok=True)
    print(f"Downloading group {name!r} -> {path}")

    segments = filter_segments(filters["include"], filters["exclude"])
    progress = tqdm(total=NUM)
    for _, row in segments.iterrows():
        if progress.n >= NUM:
            print("Target number of files reached")
            break
        file_path = path / f"{row['id']}.wav"
        if file_path.exists():
            progress.update()
            continue
        progress.set_description(f"{file_path.name}")
        ok = download_segment(row["id"], row["start"], row["end"], file_path)
        progress.update(ok)
        
    print(f"Total samples in group {name!r}: {progress.n}")
    progress.close()
# Out:
# Please check following parameters are correct:
# Group names to download: ['noise', 'music']
# Number of files to download (per group): 2000
# Output audio sample rate: 16000
# Continue? (y/n): y
# Downloading group 'noise' -> ..\datasets\audioset\noise
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# This video contains content from Lasso Group, who has blocked it on copyright grounds.
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# ERROR: Video unavailable
# ERROR: This video has been removed for violating YouTube's Terms of Service.
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: This video has been removed for violating YouTube's Community Guidelines.
# ERROR: Video unavailable
# ERROR: Video unavailable
# This video is no longer available due to a copyright claim by Alan Becker.
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: Video unavailable
# ERROR: This video has been removed for violating YouTube's Community Guidelines.
# ERROR: Video unavailable
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Video unavailable
